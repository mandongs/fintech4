# %% [markdown]
# # 주피터 노트북 사용법
# * 하위목록1 \<UL>\<LI>
#     * 하위목록2
# ## 주피터 노트북 사용법
# ### 주피터 노트북 사용법
# #### 주피터 노트북 사용법
# ##### 주피터 노트북 사용법

# %%
1+1
# Out:
# 2

# %%
2+2
# Out:
# 4

# %%
3 + 5
# Out:
# 8

# %%
a+b
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a+b
#
# NameError: name 'a' is not defined

# %%
b=20

# %% [markdown]
# # Jupyter notbook 마크다운 사용법

# %% [markdown]
# # 강조
# * **굵은 글씨**
# * *기울임*
# * ***굵고 기울임***

# %% [markdown]
# [텍스트](file:///C:/fintech4/03%20python/00_jupyter_markdown_%EA%B0%95%EC%9D%98%EC%95%88.html)

# %% [markdown]
# ---

# %% [markdown]
# > 인용문

# %% [markdown]
# ![이미지](https://png.pngtree.com/background/20230517/original/pngtree-very-long-hair-feline-looking-ahead-to-the-sun-picture-image_2623945.jpg)

# %% [markdown]
# [이미지](https://png.pngtree.com/background/20230517/original/pngtree-very-long-hair-feline-looking-ahead-to-the-sun-picture-image_2623945.jpg)

# %% [markdown]
# # 표 만들기

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# # 체크박스

# %% [markdown]
# - [x] 데이터 수집
# - [ ] 전처리
# - [ ] 모델 학습

# %% [markdown]
# # 수식

# %% [markdown]
# $y = ax + b$

# %% [markdown]
# $$
# \sum_{i=1}^{n} x_i
# $$
