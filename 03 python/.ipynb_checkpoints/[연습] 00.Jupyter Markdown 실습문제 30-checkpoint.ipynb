# %% [markdown]
# -- 1
#
# # 내 첫 번째 노트북

# %% [markdown]
# -- 2
#
# ## 실습 목표

# %% [markdown]
# -- 3
#
# 데이터 분석은 질문에서 시작한다.\
# 좋은 질문이 좋은 결과를 만든다.

# %% [markdown]
# --4
#
# 첫 줄\
# 둘째 줄

# %% [markdown]
# -- 5
#
# **중요**

# %% [markdown]
# --6
#
# *주의*

# %% [markdown]
# --7
#
# ***핵심***

# %% [markdown]
# --8
#
# 변수는 `x = 10` 으로 만든다.

# %% [markdown]
# --9
#
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# --10
#
# 1. 수집
# 2. 정제
# 3. 학습

# %% [markdown]
# --11
#
# - 과일
#     - 사과
#     - 바나나

# %% [markdown]
# --12
#
# >측정할 수 없으면 개선할 수 없다.

# %% [markdown]
# --13
#
# ---

# %% [markdown]
# --14
#
# [OpenAI](https://www.openai.com)

# %% [markdown]
# --15
#
# ![sample](images/sample.png)

# %% [markdown]
# --16
#
# | 이름 | 나이 |
# |---|---|
# | 철수 | 20 |
# | 영희 | 21 |

# %% [markdown]
# --17
#
# | 이름 | 나이 | 성별 |
# |:---|:---:|---:|
# | 철수 | 20 | 여 |
# | 영희 | 21 | 남 |

# %% [markdown]
# --18
#
# - [x] 일
# - [ ] 일
# - [ ] 일

# %% [markdown]
# --19
#
# ```python
# print("hello")
# ```

# %% [markdown]
# --20
#
# ```SQL
# SELECT * FROM film LIMIT 5;
# ```

# %% [markdown]
# --21
#
# 직선은 $y = ax + b$ 로 표현한다.

# %% [markdown]
# --22
#
# $$
# \sum_{i=1}^{n} x_i
# $$

# %% [markdown]
# --23
#
# ## 오늘 할 일
#
# - 노트북 정리
# - 실습
# - 복습

# %% [markdown]
# --24
#
# >**중요**한 것은 꾸준함이다.

# %% [markdown]
# --25
#
# [문서](https://example.com) `README.md`

# %% [markdown]
# --26
#
# ### 진행상황
#
# - [x] 데이터 수집
# - [x] 전처리
# - [ ] 모델 학습

# %% [markdown]
# --27
#
# | 항목 | 값 |
# |:---|---:|
# | 정확도 | 0.93 |
# | 손실 | 0.12 |

# %% [markdown]
# --28
#
# # 데이터 분석 보고서
# ## 1. 문제 정의
# 한 줄 설명
# ## 2. 데이터
# 한 줄 설명

# %% [markdown]
# --29
#
# 예제 코드
#
# ```Python
# nums = [1, 2, 3]
# sum(nums)
# ```

# %% [markdown]
# --30
#
# ## 요약
# > 결과는 재현 가능해야 한다.
# - [x] 데이터 저장
# - [ ] 리포트 작성
# ---
# `E = mc^2`이다.
