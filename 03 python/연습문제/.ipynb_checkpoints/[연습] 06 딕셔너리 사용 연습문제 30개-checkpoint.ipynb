# %%
--1

empty_dict = {}
empty_dict
# Out:
# {}

# %%
--2

person = {"name": "Alice", "age": 25, "city": "Seoul"}
print(person,type(person))
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'} <class 'dict'>

# %%
--3

person['name']
person.get('name', 'key 없음')
# Out:
# 'Alice'

# %%
--4

person.get('age')
# Out:
# 25

# %%
--5

person.update(job= "Engineer")
# person setdefault("job", "Engineer")
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Engineer'}

# %%
--6

person.update(city= "Busan")
# person['city']='busan'
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Engineer'}

# %%
--7

#del person['age']
person.pop('age')
person
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %%
--8

#for key in person:
    #print(key)
person.keys()
# Out:
# dict_keys(['name', 'city', 'job'])

# %%
--9

person.values()
# Out:
# dict_values(['Alice', 'Busan', 'Engineer'])

# %%
--10

person.items()
# Out:
# dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')])

# %%
--11

'email' in person
# Out:
# False

# %%
--12

person.pop('job')
person
# Out:
# {'name': 'Alice', 'city': 'Busan'}

# %%
--13

person.clear()
person
# Out:
# {}

# %%
--14

student = {"name": "Bob",
 "grades": {"math": 85, "science": 90, "history": 80}}
student
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80}}

# %%
--15

print(student["grades"]["science"])
# Out:
# 90

# %%
--16

student["grades"]["english"] = 95
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80, 'english': 95}}

# %%
--17

student["grades"]['math'] = 88
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95}}

# %%
--18

del student["grades"]['history']
student
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %%
student
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %%
student["grades"]["math"]+ student["grades"]["science"]+ student["grades"]["english"]
# Out:
# 273

# %%
--19

#student.setdefault("total", student["grades"]["math"]
student['total'] = student["grades"]["math"]+ student["grades"]["science"]+ student["grades"]["english"]

print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}, 'total': 273}

# %%
--20

student['grades'].update(english=100, history=80)
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 100, 'history': 80},
#  'total': 273}

# %%
--21

courses = dict(programming= dict(python=50, java=30, Cpp=20),
              design=dict(Photoshop=25, Illustrator=15))
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
--22

courses['programming']['python']
# Out:
# 50

# %%
--23

courses['programming']['Cpp'] = 25
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
--24

#courses['design'].pop('Photoshop')
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Illustrator': 15}}

# %%
--25

courses['programming'].update(JavaScript=50)
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 50},
#  'design': {'Illustrator': 15}}

# %%
--26

courses['programming'].keys()
# Out:
# dict_keys(['python', 'java', 'Cpp', 'JavaScript'])

# %%
--27

courses['design'].items()
# Out:
# dict_items([('Illustrator', 15)])

# %%
--28

#courses.pop('design')
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 50}}

# %%
--29

'programming' in courses
# Out:
# True

# %%
--30

courses.get('design', 'design key 없음')
# Out:
# 'design key 없음'
